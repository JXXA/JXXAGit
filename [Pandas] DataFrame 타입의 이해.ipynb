# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. DataFrame

# %% [markdown]
# #### 1) DataFrame 정의
# * Series가 1차원이라면 DataFrame은 2차원
# * **Excel Sheet에 비유**하면 이해하기 쉬움
# * 인덱스가 **Row, Column**으로 구성
#     * **Row**는 각 **개별 데이터**를, **Column**은 **개별 속성**을 의미

# %%
# Data 출처는 Kaggle
train_data = pd.read_csv('./train.csv')

# %% [markdown]
# #### 2) Dataframe 데이터 파악 하기
# * head, tail 함수
# * shape 속성 (row, column)
# * describe 함수 (숫자형 데이터의 통계 계산)
# * info 함수 (데이터 타입 및 Itme 개수 등 출력)

# %%
train_data.head(n=2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# #### Index와 Columns

# %%
## 데이터 Index 조회
train_data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
## 데이터 컬럼 조회
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### 3) Dataframe 생성 (Dummy)

# %%
#########################################
## [1] Dictionery 타입으로부터 생성
#########################################
# data의 key값은 컬럼명에 해당
data = {'a' : [1,2,3], 'b' : [4,5,6], 'c' : [7,8,9]}

pd.DataFrame(data, index=['x', 'y', 'z'])

#########################################
## [2] Sereis 타입으로부터 생성
#########################################

a = pd.Series([100,200,300], ['a','b','c'])
b = pd.Series([100,222,352], ['a','b','c'])
c = pd.Series([6,25,3110], ['a','b','c'])

pd.DataFrame([a,b,c], index=['x', 'y', 'z'])
# Out:
#      a    b     c
# x  100  200   300
# y  100  222   352
# z    6   25  3110

# %% [markdown]
# #### 4) 데이터 파일 읽어오기 (read_csv)
# * sep : 구분자 설정
# * header : Header가 존재하지 않는 경우, None 선언
# * index_col : index로 사용할 column 설정
# * usecols : 실제로 DataFrame으로 로딩할 컬럼 설정

# %%
train_data = pd.read_csv('./train.csv', index_col='PassengerId', usecols=['PassengerId', 'Name', 'Age'])
train_data
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# 13                              Saundercock, Mr. William Henry  20.0
# 14                                 Andersson, Mr. Anders Johan  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   55.0
# 17                                        Rice, Master. Eugene   2.0
# 18                                Williams, Mr. Charles Eugene   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
# 20                                     Masselmani, Mrs. Fatima   NaN
# 21                                        Fynney, Mr. Joseph J  35.0
# 22                                       Beesley, Mr. Lawrence  34.0
# 23                                 McGowan, Miss. Anna "Annie"  15.0
# 24                                Sloper, Mr. William Thompson  28.0
# 25                               Palsson, Miss. Torborg Danira   8.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0
# 27                                     Emir, Mr. Farred Chehab   NaN
# 28                              Fortune, Mr. Charles Alexander  19.0
# 29                               O'Dwyer, Miss. Ellen "Nellie"   NaN
# 30                                         Todoroff, Mr. Lalio   NaN
# ...                                                        ...   ...
# 862                                Giles, Mr. Frederick Edward  21.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0
# 864                          Sage, Miss. Dorothy Edith "Dolly
Abelson, Mrs. Samuel (Hannah Wizosky)
# 875              2667                   Najib, Miss. Adele Kiamie "Jane"
# 876              7534                      Gustafsson, Mr. Alfred Ossian
# 877            349212                               Petroff, Mr. Nedelio
# 878            349217                                 Laleff, Mr. Kristo
# 879             11767      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880            230433       Shelley, Mrs. William (Imanita Parrish Hall)
# 881            349257                                 Markun, Mr. Johann
# 882              7552                       Dahlberg, Miss. Gerda Ulrika
# 883  C.A./SOTON 34068                      Banfield, Mr. Frederick James
# 884   SOTON/OQ 392076                             Sutehall, Mr. Henry Jr
# 885            382652               Rice, Mrs. William (Margaret Norton)
# 886            211536                              Montvila, Rev. Juozas
# 887            112053                       Graham, Miss. Margaret Edith
# 888        W./C. 6607           Johnston, Miss. Catherine Helen "Carrie"
# 889            111369                              Behr, Mr. Karl Howell
# 890            370376                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %% [markdown]
# #### 6) Row 선택
# * **Series는 []**를 통해 Row를 선택 -> **DataFrame은 loc 또는 iloc 이용** 하여 Row 선택
# * 아래 함수는 column 선택 시에도 사용 가능
#     * loc : 명시된 인덱스 값을 사용
#     * iloc : 0 based index로 사용 (어떤 인덱스 값이든 내부적으로 가진 0부터의 값으로 가져온다)

# %%
## 데이터 슬라이싱 
# []는 보통 컬럼 선택에 사용하나 슬라이싱만 예외
train_data[:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
## 인덱스 값을 가져오기 위해 임의적으로 인덱스 값 변경
train_data.index = np.arange(100, 991)
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 986          887         0       2                     Montvila, Rev. Juozas
# 987          888         1       1              Graham, Miss. Margaret Edith
# 988          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 989          890         1       1                     Behr, Mr. Karl Howell
# 990          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 986    male  27.0      0      0      211536  13.00   NaN        S
# 987  female  19.0      0      0      112053  30.00   B42        S
# 988  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 989    male  26.0      0      0      111369  30.00  C148        C
# 990    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_data.loc[989] # 단일 값

train_data.loc[[989,100,102]] # 다중 값
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 989          890         1       1    Behr, Mr. Karl Howell    male  26.0
# 100            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 102            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#      SibSp  Parch            Ticket    Fare Cabin Embarked
# 989      0      0            111369  30.000  C148        C
# 100      1      0         A/5 21171   7.250   NaN        S
# 102      0      0  STON/O2. 3101282   7.925   NaN        S

# %%
# 명시된 Index가 따로 존재하지만, 해당 값들은 내부적으로 
# 0부터 시작된 값을 참고할 수 있음
train_data.iloc[[0,1]]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#      Parch     Ticket     Fare Cabin Embarked
# 100      0  A/5 21171   7.2500   NaN        S
# 101      0   PC 17599  71.2833   C85        C

# %% [markdown]
# #### 참고) Column과 Row 를 동시에 가져올 경우

# %%
train_data.loc[[989,100,102], ['Name', 'Age', 'Fare']] # 다중 값
# Out:
#                         Name   Age    Fare
# 989    Behr, Mr. Karl Howell  26.0  30.000
# 100  Braund, Mr. Owen Harris  22.0   7.250
# 102   Heikkinen, Miss. Laina  26.0   7.925
